# %%
import sys,os
import numpy as np
#import matplotlib
#matplotlib.use('TkAgg')
# %matplotlib qt
import matplotlib.pyplot as plt

#%matplotlib inline
from scipy.signal import savgol_filter

# %%
path_norm = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/CELEX/normal_run_1/'
path_lds = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/CELEX/lds_run_2/'
path_leave = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/CELEX/interleaved_run_2/'
path_vl = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/CELEX/intervened_+_interleaved_run_1/'
path_vene = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/CELEX/intervened_run_0/'
normal_cel = dict(np.load(path_norm+'metrics.npz'))
lds_cel    = dict(np.load(path_lds+'metrics.npz'))
leave_cel    = dict(np.load(path_leave+'metrics.npz'))
vl_cel    = dict(np.load(path_vl+'metrics.npz'))
vene_cel = dict(np.load(path_vene+'metrics.npz'))


p_norm = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/normal_run_0/'
p_lds = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/lds_run_0/'
p_leave = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/interleaved_run_0/'
p_vene = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/intervened_run_0/'
p_v_l = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/intervened + interleaved_run_0/'
normal_child = dict(np.load(p_norm+'/metrics.npz'))
lds_child    = dict(np.load(p_lds+'/metrics.npz'))
leave_child    = dict(np.load(p_leave+'/metrics.npz'))
vene_child    = dict(np.load(p_vene+'/metrics.npz'))
vene_leave_child    = dict(np.load(p_v_l+'/metrics.npz'))

save_child = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/'
save_celex = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/celex_all/'

# %%
perf = np.arange(250)
xticks_25 = np.arange(25,251,25)
xticks = np.arange(50,251,50)

# %%
# Childlex - Training - Token accuracy plot 
plt.plot(perf_250,savgol_filter(np.squeeze(lds_child['trainPerf'][:-1,0]),5,1),color='firebrick',linewidth=4,label='LdS writing module')
plt.plot(perf_250,savgol_filter(np.squeeze(lds_child['trainPerf'][:-1,3]),5,1),color='tomato',linewidth=4,label='LdS reading module')
plt.plot(perf_250,savgol_filter(np.squeeze(normal_child['trainPerf'][:-1,0]),5,1),color='forestgreen',linewidth=4,label='Regular writing module')
plt.plot(perf_250, savgol_filter(np.squeeze(normal_child['trainPerf'][:-1,3]),5,1),color='springgreen',linewidth=4,label='Regular reading module')

plt.title("Childlex dataset - Token accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_250,xticklabels)
plt.legend(loc=4)
plt.ylim([0.9, 1.005])
plt.axvline(125,color='k')
plt.show()
plt.savefig(save_child+'Training Token Acc')

# Do not show, perfect accuracies (use word acc instead)

# %%
# Childlex - testing - word acc
plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['testPerf'][:-1,1]),5,1),color='firebrick',linewidth=4,label='LdS writing module')
plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['testPerf'][:-1,3]),5,1),color='tomato',linewidth=4,label='LdS reading module')
plt.plot(perf_x,savgol_filter(np.squeeze(normal_child['testPerf'][:-1,1]),5,1),color='forestgreen',linewidth=4,label='Regular writing module')
plt.plot(perf_x, savgol_filter(np.squeeze(normal_child['testPerf'][:-1,3]),5,1),color='springgreen',linewidth=4,label='Regular reading module')

plt.title("Childlex dataset - Word accuracy - Test data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_250,xticklabels)
plt.legend(loc=4)
plt.axvline(125,color='k')
plt.show()
plt.savefig(save_child+'Training Token Acc')

# Do not show, perfect accuracies (use word acc instead)

# %%
# Childlex - Training - Word ratio accuracy plots
plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['lds_ratios']),5,1),color='firebrick',linewidth=4,label='LdS model - alt. spellings')
plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['trainPerf'][:-1,1]),5,1),color='tomato',linewidth=4,label='LdS model - 1 spelling')
plt.plot(perf_x,savgol_filter(np.squeeze(normal_child['lds_ratios']),5,1),color='forestgreen',linewidth=4,label='Regular model - alt. spellings')
plt.plot(perf_x,savgol_filter(np.squeeze(normal_child['trainPerf'][:-1,1]),5,1),color='springgreen',linewidth=4,label='Regular - 1 spellings')

plt.title("Childlex dataset - Ratio of correct words")
plt.ylabel("Ratio")
plt.xlabel("Epochs")
plt.xticks(xticks_250,xticklabels)
plt.legend(loc=5)
#plt.ylim([0, 0.6])
plt.axvline(125,color='k')
plt.show()
plt.savefig(save_child+'Training Word ratios')


# SHOW THIS ONE

# %%
# Childlex - Testing - Word ratio accuracy plots
plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['lds_ratios_test'][:-1]),5,1),color='firebrick',linewidth=4,label='LdS model - alt. spellings')
plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['testPerf'][:-1,1]),5,1),color='tomato',linewidth=4,label='LdS model - 1 spelling')
plt.plot(perf_x,savgol_filter(np.squeeze(normal_child['lds_ratios_test'][:-1]),5,1),color='forestgreen',linewidth=4,label='Regular model - alt. spellings')
plt.plot(perf_x,savgol_filter(np.squeeze(normal_child['testPerf'][:-1,1]),5,1),color='springgreen',linewidth=4,label='Regular - 1 spellings')

plt.title("Childlex dataset - Ratio of correct words")
plt.ylabel("Ratio")
plt.xlabel("Epochs")
plt.xticks(xticks_250,xticklabels)
plt.legend(loc=5)
#plt.ylim([0, 0.6])
plt.axvline(125,color='k')
plt.show()
plt.savefig(save_child+'Testing Word ratios')


# DO NOT SHOW THIS ONE

# %%
# Childlex - Training - Loss
#plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['lds_loss']),3,1),color='firebrick',linewidth=4,label='LdS model - lds loss')
#plt.plot(perf_x,savgol_filter(np.squeeze(lds_child['write_loss']),3,1),color='tomato',linewidth=4,label='LdS model - regular loss')
plt.plot(perf_x,normal_child['write_loss']/normal_child['lds_loss'],color='forestgreen',linewidth=4,label='Regular model')
plt.plot(perf_x,lds_child['write_loss']/lds_child['lds_loss'],color='springgreen',linewidth=4,label='LdS model')

plt.title("Childlex dataset - Writing loss ratio")
plt.ylabel("Regular loss / LdS loss")
plt.xlabel("Epochs")
#plt.xticks(xticks_p,xticklabels)
plt.legend(loc='best')
plt.ylim([0, 3.5])
plt.axvline(125,color='k')
plt.show()
plt.savefig(save_child+'Training writing loss development')

# DO NOT SHOW

# %%
# Make Figure with 4 subplots
perf_x = perf_250
xticks_250_bigsteps = np.arange(50,251,50)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
#fig.tight_layout()
#fig.set_figheight(5)
#fig.set_figwidth(5)
fig.suptitle("Childlex corpus", fontsize=15, weight='bold' )


# Childlex - Training - Word accuracy plot - all regimes - Writing
ind =1
ax1.plot(perf_x,savgol_filter(np.squeeze(normal_child['trainPerf'][:-1,ind]),5,1),color='forestgreen',linewidth=4,label='Regular')
ax1.plot(perf_x,savgol_filter(np.squeeze(lds_child['trainPerf'][:-1,ind]),5,1),color='firebrick',linewidth=4,label='LdS')
ax1.plot(perf_x,savgol_filter(np.squeeze(leave_child['trainPerf'][:-1,ind]),5,1),color='tomato',linewidth=4,label='Replay')
ax1.plot(perf_x, savgol_filter(np.squeeze(vene_child['trainPerf'][:-1,ind]),5,1),color='springgreen',linewidth=4,label='Intervene')
ax1.plot(perf_x, savgol_filter(np.squeeze(vene_leave_child['trainPerf'][:-1,ind]),5,1),color='dodgerblue',linewidth=4,label='I + R')

ax1.set_title("Training - Writing module",{'fontsize':12})
ax1.set_ylabel("Word accuracy")
ax1.set_xticks(xticks_250_bigsteps)
ax1.legend(loc=4, prop={'size': 8})
ax1.set_ylim([0.75, 1.0])
ax1.set_xlim([0, 250])
ax1.axvline(125,color='k')

# Childlex - Training - Word accuracy plot - all regimes - Reading
ind =4
ax2.plot(perf_x,savgol_filter(np.squeeze(normal_child['trainPerf'][:-1,ind]),5,1),color='forestgreen',linewidth=4,label='Regular')
ax2.plot(perf_x,savgol_filter(np.squeeze(lds_child['trainPerf'][:-1,ind]),5,1),color='firebrick',linewidth=4,label='LdS')
ax2.plot(perf_x,savgol_filter(np.squeeze(leave_child['trainPerf'][:-1,ind]),5,1),color='tomato',linewidth=4,label='Replay')
ax2.plot(perf_x, savgol_filter(np.squeeze(vene_child['trainPerf'][:-1,ind]),5,1),color='springgreen',linewidth=4,label='Intervene')
ax2.plot(perf_x, savgol_filter(np.squeeze(vene_leave_child['trainPerf'][:-1,ind]),5,1),color='dodgerblue',linewidth=4,label='I + R')

ax2.set_title("Training - Reading module",{'fontsize':12})
ax2.set_ylabel("Word accuracy")
ax2.set_xticks(xticks_250_bigsteps)
ax2.legend(loc=4, prop={'size': 8})
ax2.set_xlim([0, 250])
ax2.set_ylim([0.75, 1.0])
ax2.axvline(125,color='k')

# Childlex - Training - Word ratio accuracy plots
ax3.plot(perf_x,savgol_filter(np.squeeze(normal_child['trainPerf'][:-1,1]),5,1),color='forestgreen',linewidth=4,label='Regular - true spelling')
ax3.plot(perf_x,savgol_filter(np.squeeze(lds_child['trainPerf'][:-1,1]),5,1),color='firebrick',linewidth=4,label='LdS - true spelling')
ax3.plot(perf_x,savgol_filter(np.squeeze(lds_child['lds_ratios']),5,1),color='tomato',linewidth=4,label='LdS - alt. spellings')
ax3.plot(perf_x,savgol_filter(np.squeeze(normal_child['lds_ratios']),5,1),color='springgreen',linewidth=4,label='Regular - alt. spellings')

ax3.set_title("Training - Writing - Word correctnesses")
ax3.set_ylabel("Ratio")
ax3.set_xlabel("Epochs")
ax3.set_xticks(xticks_250_bigsteps)
ax3.legend(loc=5, prop={'size': 8})
ax3.set_ylim([0, 1])
ax3.axvline(125,color='k')


# Childlex - Testing - Word ratio accuracy plots
ax4.plot(perf_x,savgol_filter(np.squeeze(normal_child['testPerf'][:-1,1]),5,1),color='forestgreen',linewidth=4,label='Regular - true spelling')
ax4.plot(perf_x,savgol_filter(np.squeeze(lds_child['testPerf'][:-1,1]),5,1),color='firebrick',linewidth=4,label='LdS - true spelling')
ax4.plot(perf_x,savgol_filter(np.squeeze(lds_child['lds_ratios_test'][:-1]),5,1),color='tomato',linewidth=4,label='LdS - alt. spellings')
ax4.plot(perf_x,savgol_filter(np.squeeze(normal_child['lds_ratios_test'][:-1]),5,1),color='springgreen',linewidth=4,label='Regular - alt. spellings')

ax4.set_title("Testing - Writing - Word correctnesses")
ax4.set_ylabel("Ratio")
ax4.set_xlabel("Epochs")
ax4.set_xticks(xticks_250_bigsteps)
ax4.legend(loc=1, prop={'size': 8})
ax4.set_ylim([0, 0.5])
ax4.axvline(125,color='k')

# %% [markdown]
# # CELEX DATA

# %%
# repair CELEX DATA
inds = [0,1,2,3,4]

for ind in inds:

    plt.plot(lds_cel['trainPerf'][:-1,ind])
    plt.plot(normal_cel['trainPerf'][:-1,ind])
    plt.plot(leave_cel['trainPerf'][:-1,ind])
    plt.plot(vl_cel['trainPerf'][:-1,ind])
    plt.show()
    
t = 0.95

for ind in inds:
    for k in range(3,len(lds_cel['trainPerf'][:-1,ind])-3):
        if lds_cel['trainPerf'][k,ind] <t*np.mean(lds_cel['trainPerf'][k-2:k+3,ind]):
            print(k,lds_cel['trainPerf'][k,ind],np.mean(lds_cel['trainPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            lds_cel['trainPerf'][k,ind] = np.mean(lds_cel['trainPerf'][ids,ind])
            print(lds_cel['trainPerf'][k,ind] )

    for k in range(3,len(normal_cel['trainPerf'][:-1,ind])-3):
        if normal_cel['trainPerf'][k,ind] < t*np.mean(normal_cel['trainPerf'][k-2:k+3,ind]):
            print(k,normal_cel['trainPerf'][k,ind],np.mean(normal_cel['trainPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            normal_cel['trainPerf'][k,ind] = np.mean(normal_cel['trainPerf'][ids,ind])
            print(normal_cel['trainPerf'][k,ind] )
            
    for k in range(3,len(leave_cel['trainPerf'][:-1,ind])-3):
        if leave_cel['trainPerf'][k,ind] < t*np.mean(leave_cel['trainPerf'][k-2:k+3,ind]):
            print(k,leave_cel['trainPerf'][k,ind],np.mean(leave_cel['trainPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            leave_cel['trainPerf'][k,ind] = np.mean(leave_cel['trainPerf'][ids,ind])
            print(leave_cel['trainPerf'][k,ind] )   
            
    for k in range(3,len(vl_cel['trainPerf'][:-1,ind])-3):
        if vl_cel['trainPerf'][k,ind] < t*np.mean(vl_cel['trainPerf'][k-2:k+3,ind]):
            print(k,vl_cel['trainPerf'][k,ind],np.mean(vl_cel['trainPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            vl_cel['trainPerf'][k,ind] = np.mean(vl_cel['trainPerf'][ids,ind])
            print(vl_cel['trainPerf'][k,ind] )
            
            
    for k in range(3,len(vene_cel['trainPerf'][:-1,ind])-3):
        if vene_cel['trainPerf'][k,ind] < t*np.mean(vene_cel['trainPerf'][k-2:k+3,ind]):
            print(k,vene_cel['trainPerf'][k,ind],np.mean(vene_cel['trainPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            vene_cel['trainPerf'][k,ind] = np.mean(vene_cel['trainPerf'][ids,ind])
            print(vene_cel['trainPerf'][k,ind] )       
            
    plt.plot(lds_cel['trainPerf'][:-1,ind])
    plt.show()  
    
inds = [0,1,2,3]
for ind in inds:
    for k in range(3,len(normal_cel['testPerf'][:-1,ind])-3):
        if normal_cel['testPerf'][k,ind] < t*np.mean(normal_cel['testPerf'][k-2:k+3,ind]):
            print(k,normal_cel['testPerf'][k,ind],np.mean(normal_cel['testPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            normal_cel['testPerf'][k,ind] = np.mean(normal_cel['testPerf'][ids,ind])
            print(normal_cel['testPerf'][k,ind] )

    for k in range(3,len(lds_cel['testPerf'][:-1,ind])-3):
        if lds_cel['testPerf'][k,ind] < t*np.mean(lds_cel['testPerf'][k-2:k+3,ind]):
            print(k,lds_cel['testPerf'][k,ind],np.mean(lds_cel['testPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            lds_cel['testPerf'][k,ind] = np.mean(lds_cel['testPerf'][ids,ind])
            print(lds_cel['testPerf'][k,ind] )
        


    for k in range(3,len(leave_cel['testPerf'][:-1,ind])-3):
        if leave_cel['testPerf'][k,ind] < t*np.mean(leave_cel['testPerf'][k-2:k+3,ind]):
            print(k,leave_cel['testPerf'][k,ind],np.mean(leave_cel['testPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            leave_cel['testPerf'][k,ind] = np.mean(leave_cel['testPerf'][ids,ind])
            print(leave_cel['testPerf'][k,ind] )   
            
    for k in range(3,len(vl_cel['testPerf'][:-1,ind])-3):
        if vl_cel['testPerf'][k,ind] < t*np.mean(vl_cel['testPerf'][k-2:k+3,ind]):
            print(k,vl_cel['testPerf'][k,ind],np.mean(vl_cel['testPerf'][k-2:k+3,ind]) )
            ids = [l for l in range(k-2,k+3) if not l==k]
            print(ids)
            vl_cel['testPerf'][k,ind] = np.mean(vl_cel['testPerf'][ids,ind])
            print(vl_cel['testPerf'][k,ind] )




    plt.plot(normal_cel['testPerf'][:-1,ind])
    plt.show()
# Out:
# 15 0.7506428360939026 0.8940458924709995
# [13, 14, 16, 17]
# 0.9298966565652739
# 153 0.8838096596772158 0.9741767785971678
# [151, 152, 154, 155]
# 0.9967685583271557
# 11 0.7222316879306347 0.8909312179245923
# [9, 10, 12, 13]
# 0.933106100423082
# 32 0.8599327494045199 0.9505302771699006
# [30, 31, 33, 34]
# 0.9731796591112456
# 59 0.9156211517789037 0.9744776342120872
# [57, 58, 60, 61]
# 0.9891917548203832
# 3 0.010131645569620254 0.051069367088607584
# [1, 2, 4, 5]
# 0.06130379746835442
# 4 0.07778987341772152 0.10154683544303797
# [2, 3, 5, 6]
# 0.10748607594936707
# 6 0.20123037974683547 0.2418658227848101
# [4, 5, 7, 8]
# 0.25202468354430385
# 10 0.2741746835443038 0.4076359493670886
# [8, 9, 11, 12]
# 0.4410012658227848
# 12 0.3210151898734177 0.4673541772151898
# [10, 11, 13, 14]
# 0.5039389240506329
# 15 0.09448860759493671 0.38605215189873415
# [13, 14, 16, 17]
# 0.4589430379746835
# 16 0.34742278481012656 0.4623455696202531
# [14, 15, 17, 18]
# 0.4910762658227848
# 19 0.45103544303797466 0.4871513924050633
# [17, 18, 20, 21]
# 0.49618037974683543
# 20 0.3589620253164557 0.45503506329113924
# [18, 19, 21, 22]
# 0.47905332278481016
# 22 0.2829721518987342 0.4630071202531646
# [20, 21, 23, 24]
# 0.5080158623417721
# 24 0.42858987341772153 0.5252198813291139
# [22, 23, 25, 26]
# 0.549377383306962
# 25 0.4837063291139241 0.5843164893196202
# [23, 24, 26, 27]
# 0.6094690293710443
# 26 0.5804582278481013 0.6351135863330696
# [24, 25, 27, 28]
# 0.6487774259543116
# 29 0.509893670886076 0.6006739240506329
# [27, 28, 30, 31]
# 0.6233689873417723
# 30 0.5329088607594937 0.6224403797468355
# [28, 29, 31, 32]
# 0.6448232594936709
# 31 0.5243037974683544 0.6448799683544305
# [29, 30, 32, 33]
# 0.6750240110759494
# 35 0.6392253164556962 0.7118906329113923
# [33, 34, 36, 37]
# 0.7300569620253164
# 36 0.639506329113924 0.7195683544303797
# [34, 35, 37, 38]
# 0.7395838607594937
# 39 0.4935291139240506 0.6963584810126582
# [37, 38, 40, 41]
# 0.7470658227848102
# 42 0.4704759493670886 0.7092192405063291
# [40, 41, 43, 44]
# 0.7689050632911392
# 50 0.7282455696202532 0.8174075949367088
# [48, 49, 51, 52]
# 0.8396981012658227
# 55 0.6633772151898734 0.783793924050633
# [53, 54, 56, 57]
# 0.8138981012658228
# 153 0.15949113924050634 0.8109984810126581
# [151, 152, 154, 155]
# 0.9738753164556961
# 3 0.08597715736040608 0.11070101522842642
# [1, 2, 4, 5]
# 0.11688197969543149
# 11 0.04468781725888324 0.3758106598984772
# [9, 10, 12, 13]
# 0.4585913705583756
# 12 0.3413959390862944 0.4591578680203046
# [10, 11, 13, 14]
# 0.48859835025380716
# 14 0.4929695431472081 0.5284359137055837
# [12, 13, 15, 16]
# 0.5373025063451776
# 15 0.48684517766497465 0.5701726840101523
# [13, 14, 16, 17]
# 0.5910045605964467
# 16 0.5073401015228426 0.5707314641497462
# [14, 15, 17, 18]
# 0.586579304806472
# 18 0.5650609137055838 0.6015336274587563
# [16, 17, 19, 20]
# 0.6106518058970495
# 19 0.4940126903553299 0.6323415286921003
# [17, 18, 20, 21]
# 0.6669237382762928
# 24 0.6621040609137057 0.7436451776649746
# [22, 23, 25, 26]
# 0.7640304568527918
# 32 0.2742715736040609 0.6551710659898478
# [30, 31, 33, 34]
# 0.7503959390862944
# 43 0.7953401015228427 0.8607715736040609
# [41, 42, 44, 45]
# 0.8771294416243656
# 52 0.7863883248730964 0.8814532994923857
# [50, 51, 53, 54]
# 0.9052195431472081
# 66 0.8875456852791878 0.9483177664974619
# [64, 65, 67, 68]
# 0.9635107868020305
# 6 0.234997461928934 0.28288324873096443
# [4, 5, 7, 8]
# 0.2948546954314721
# 8 0.24338832487309645 0.3586521573604061
# [6, 7, 9, 10]
# 0.3874681154822335
# 9 0.37178426395939085 0.4325860088832488
# [7, 8, 10, 11]
# 0.44778644511421317
# 13 0.433756345177665 0.5013649746192893
# [11, 12, 14, 15]
# 0.5182671319796954
# 15 0.519753807106599 0.5568767766497462
# [13, 14, 16, 17]
# 0.566157519035533
# 21 0.593489847715736 0.6327842639593908
# [19, 20, 22, 23]
# 0.6426078680203046
# 22 0.6126573604060914 0.6565063451776649
# [20, 21, 23, 24]
# 0.6674685913705584
# 25 0.5948060913705584 0.6776381725888324
# [23, 24, 26, 27]
# 0.6983461928934009
# 29 0.6544463197969543 0.7113084010152283
# [27, 28, 30, 31]
# 0.7255239213197968
# 33 0.4338100253807107 0.6728763197969543
# [31, 32, 34, 35]
# 0.7326428934010151
# 43 0.7174790609137054 0.7801298730964467
# [41, 42, 44, 45]
# 0.7957925761421321
# 56 0.6636232233502538 0.8070471827411169
# [54, 55, 57, 58]
# 0.8429031725888325
# 61 0.7620133248730966 0.8166629187817259
# [59, 60, 62, 63]
# 0.8303253172588831
# 86 0.8350861675126903 0.8806924365482234
# [84, 85, 87, 88]
# 0.8920940038071065
# 3 0.002050761421319797 0.08778629441624367
# [1, 2, 4, 5]
# 0.10922017766497463
# 6 0.28243654822335024 0.2989263959390863
# [4, 5, 7, 8]
# 0.3030488578680203
# 9 0.34971065989847716 0.4185781725888325
# [7, 8, 10, 11]
# 0.43579505076142133
# 12 0.19040862944162437 0.4512634517766497
# [10, 11, 13, 14]
# 0.5164771573604061
# 13 0.46733248730964466 0.504153807106599
# [11, 12, 14, 15]
# 0.5133591370558376
# 15 0.45438832487309644 0.5648972081218274
# [13, 14, 16, 17]
# 0.5925244289340101
# 16 0.510736040609137 0.604071383248731
# [14, 15, 17, 18]
# 0.6274052189086294
# 18 0.5710939086294415 0.6308972874365482
# [16, 17, 19, 20]
# 0.6458481321383249
# 20 0.6035837563451776 0.6563274944479696
# [18, 19, 21, 22]
# 0.6695134289736675
# 23 0.48501522842639594 0.5838131979695432
# [21, 22, 24, 25]
# 0.60851269035533
# 24 0.43400253807106604 0.6040517766497462
# [22, 23, 25, 26]
# 0.6465640862944162
# 25 0.6095685279187818 0.6696681472081217
# [23, 24, 26, 27]
# 0.6846930520304568
# 26 0.6885964467005075 0.7273483819796953
# [24, 25, 27, 28]
# 0.7370363657994924
# 30 0.7098223350253807 0.773856345177665
# [28, 29, 31, 32]
# 0.7898648477157361
# 34 0.6849543147208123 0.7700903553299493
# [32, 33, 35, 36]
# 0.7913743654822335
# 38 0.6080253807106599 0.6993522842639595
# [36, 37, 39, 40]
# 0.7221840101522843
# 39 0.6219111675126904 0.725729695431472
# [37, 38, 40, 41]
# 0.7516843274111675
# 53 0.7811928934010152 0.8677223350253807
# [51, 52, 54, 55]
# 0.889354695431472
# 59 0.19493908629441628 0.7622984771573604
# [57, 58, 60, 61]
# 0.9041383248730963
# 3 0.002038647777678667 0.08802284674670979
# [1, 2, 4, 5]
# 0.10951889648896757
# 9 0.34958649855793994 0.41228383159439075
# [7, 8, 10, 11]
# 0.42795816485350346
# 12 0.18301570156358452 0.4470530218930685
# [10, 11, 13, 14]
# 0.5130623519754396
# 13 0.45895176560085393 0.5015078400272988
# [11, 12, 14, 15]
# 0.51214685863391
# 15 0.460731307270978 0.5589774479263859
# [13, 14, 16, 17]
# 0.5835389830902379
# 16 0.49937564518528454 0.596640598352536
# [14, 15, 17, 18]
# 0.620956836644349
# 18 0.5776549349454008 0.6261406048902071
# [16, 17, 19, 20]
# 0.6382620223764086
# 20 0.6083468512753125 0.6524033543166724
# [18, 19, 21, 22]
# 0.6634174800770124
# 23 0.49552010937424 0.5798384284487128
# [21, 22, 24, 25]
# 0.600918008217331
# 24 0.42169404128096294 0.5925251608836982
# [22, 23, 25, 26]
# 0.635232940784382
# 25 0.6124919415449585 0.6614931857834717
# [23, 24, 26, 27]
# 0.6737434968431002
# 26 0.6713217194588466 0.7111300236836066
# [24, 25, 27, 28]
# 0.7210820997397964
# 30 0.7128484690990198 0.7635353734826638
# [28, 29, 31, 32]
# 0.7762070995785746
# 34 0.6746894079864173 0.75877897931411
# [32, 33, 35, 36]
# 0.7798013721460333
# 38 0.6197939255538454 0.696124713321643
# [36, 37, 39, 40]
# 0.7152074102635924
# 39 0.6103658802494872 0.7167902903195158
# [37, 38, 40, 41]
# 0.7433963928370229
# 53 0.7508391509150264 0.85524555960912
# [51, 52, 54, 55]
# 0.8813471617826433
# 59 0.19237425441383796 0.7536917282020777
# [57, 58, 60, 61]
# 0.8940210966491376
# 13 0.4049989177456385 0.8148054168948644
# [11, 12, 14, 15]
# 0.9172570416821708
# 31 0.6226889807966691 0.9073353264150741
# [29, 30, 32, 33]
# 0.9784969128196752
# 13 0.7949278993049854 0.9204573999201585
# [11, 12, 14, 15]
# 0.9518397750739518
# 25 0.8120566621649689 0.9454804730899442
# [23, 24, 26, 27]
# 0.9788364258211882
# 9 0.7916868189869798 0.8966785167074447
# [7, 8, 10, 11]
# 0.9229264411375607
# 27 0.9195794342132995 0.9716873936846777
# [25, 26, 28, 29]
# 0.9847143835525223
# 73 0.9084358348459156 0.9799519829943699
# [71, 72, 74, 75]
# 0.9978310200314837
# 21 0.7532057175176398 0.9244327735779854
# [19, 20, 22, 23]
# 0.9672395375930718
# 33 0.8896660856184015 0.9631270855211364
# [31, 32, 34, 35]
# 0.9814923354968201
# 21 0.7403977319566686 0.91651750016151
# [19, 20, 22, 23]
# 0.9605474422127205
# 33 0.8610950493633913 0.9514784709705886
# [31, 32, 34, 35]
# 0.9740743263723879
# 3 0.04337468354430381 0.0757539240506329
# [1, 2, 4, 5]
# 0.08384873417721518
# 4 0.09367848101265824 0.10368417721518988
# [2, 3, 5, 6]
# 0.10618560126582277
# 6 0.09918227848101266 0.15221332278481012
# [4, 5, 7, 8]
# 0.16547108386075948
# 8 0.09785316455696202 0.243706875
# [6, 7, 9, 10]
# 0.2801703026107595
# 11 0.11867594936708864 0.24642632911392406
# [9, 10, 12, 13]
# 0.2783639240506329
# 13 1.2658227848101267e-05 0.29172696202531645
# [11, 12, 14, 15]
# 0.36465553797468353
# 14 0.27610126582278477 0.34777718354430387
# [12, 13, 15, 16]
# 0.3656961629746836
# 16 0.1939721518987342 0.40352606803797475
# [14, 15, 17, 18]
# 0.4559145470727849
# 17 0.3363063291139241 0.524809238528481
# [15, 16, 18, 19]
# 0.5719349658821202
# 21 0.40103544303797467 0.6040086075949367
# [19, 20, 22, 23]
# 0.6547518987341772
# 23 0.5805215189873417 0.6530977215189873
# [21, 22, 24, 25]
# 0.6712417721518986
# 25 0.6705949367088608 0.7164843037974683
# [23, 24, 26, 27]
# 0.7279566455696203
# 31 0.007318987341772152 0.6244222784810127
# [29, 30, 32, 33]
# 0.778698101265823
# 32 0.688848101265823 0.7730191139240508
# [30, 31, 33, 34]
# 0.7940618670886076
# 37 0.7828075949367088 0.8294840506329114
# [35, 36, 38, 39]
# 0.8411531645569621
# 42 0.8124632911392403 0.884887594936709
# [40, 41, 43, 44]
# 0.902993670886076
# 46 0.8338506329113924 0.887327088607595
# [44, 45, 47, 48]
# 0.9006962025316456
# 49 0.776886075949367 0.8654956962025316
# [47, 48, 50, 51]
# 0.8876481012658228
# 70 0.7423012658227849 0.8871615189873416
# [68, 69, 71, 72]
# 0.9233765822784811
# 99 0.9133291139240505 0.9652096202531645
# [97, 98, 100, 101]
# 0.9781797468354432
# 114 0.8594227848101267 0.9502622784810125
# [112, 113, 115, 116]
# 0.9729721518987341
# 132 0.9104810126582278 0.9710405063291138
# [130, 131, 133, 134]
# 0.9861803797468354
# 207 0.8248126582278481 0.9619367088607594
# [205, 206, 208, 209]
# 0.9962177215189874
# 3 0.1365253807106599 0.16533908629441624
# [1, 2, 4, 5]
# 0.1725425126903553
# 6 0.1109314720812183 0.23397918781725888
# [4, 5, 7, 8]
# 0.264741116751269
# 7 0.12138071065989847 0.27518375634517767
# [5, 6, 8, 9]
# 0.3136345177664974
# 9 0.2835380710659898 0.36658274111675127
# [7, 8, 10, 11]
# 0.3873439086294416
# 10 0.3359543147208122 0.4150829949238578
# [8, 9, 11, 12]
# 0.43486516497461924
# 13 0.0879492385786802 0.43668121827411166
# [11, 12, 14, 15]
# 0.5238642131979695
# 16 0.4493350253807107 0.5090619289340101
# [14, 15, 17, 18]
# 0.523993654822335
# 18 0.47995177664974614 0.618960152284264
# [16, 17, 19, 20]
# 0.6537122461928935
# 25 0.0830786802030457 0.6258045685279188
# [23, 24, 26, 27]
# 0.761486040609137
# 26 0.7192360406091372 0.7600581218274111
# [24, 25, 27, 28]
# 0.7702636421319796
# 28 0.7247994923857869 0.7880202411167513
# [26, 27, 29, 30]
# 0.8038254282994924
# 29 0.7747715736040609 0.8223158470812184
# [27, 28, 30, 31]
# 0.8342019154505076
# 33 0.808984771573604 0.8697842639593908
# [31, 32, 34, 35]
# 0.8849841370558376
# 37 0.8252538071065991 0.8763111675126904
# [35, 36, 38, 39]
# 0.8890755076142133
# 38 0.8072791878172588 0.8939069796954315
# [36, 37, 39, 40]
# 0.9155639276649747
# 42 0.8068426395939086 0.9008898477157361
# [40, 41, 43, 44]
# 0.9244016497461928
# 69 0.8533730964467005 0.9476959390862942
# [67, 68, 70, 71]
# 0.9712766497461929
# 80 0.8287487309644668 0.9496949238578679
# [78, 79, 81, 82]
# 0.9799314720812183
# 154 0.8174644670050761 0.9604862944162438
# [152, 153, 155, 156]
# 0.9962417512690357
# 9 0.13601565641240562 0.24931889496308218
# [7, 8, 10, 11]
# 0.2776447046007513
# 10 0.274465147770113 0.32364088657656265
# [8, 9, 11, 12]
# 0.3359348212781751
# 14 0.3610276249351456 0.5133782723485956
# [12, 13, 15, 16]
# 0.5514659342019581
# 18 0.4945027997364588 0.6197724226844955
# [16, 17, 19, 20]
# 0.6510898284215048
# 20 0.5199437637412118 0.6440858086091101
# [18, 19, 21, 22]
# 0.6751213198260848
# 21 0.5166752607418476 0.6815889248944588
# [19, 20, 22, 23]
# 0.7228173409326115
# 23 0.6834278537633749 0.7350335008867364
# [21, 22, 24, 25]
# 0.7479349126675768
# 24 0.7101733020817648 0.7551717882731139
# [22, 23, 25, 26]
# 0.7664214098209512
# 27 0.4838210715234469 0.7332670561766763
# [25, 26, 28, 29]
# 0.7956285523399836
# 31 0.6582253548590657 0.7903822900169845
# [29, 30, 32, 33]
# 0.8234215238064642
# 32 0.786873267499168 0.8341416453319728
# [30, 31, 33, 34]
# 0.845958739790174
# 38 0.6736720977711201 0.8144401269969628
# [36, 37, 39, 40]
# 0.8496321343034233
# 53 0.8670514563627278 0.9192723859839784
# [51, 52, 54, 55]
# 0.932327618389291
# 73 0.4550620097705906 0.8455598124825336
# [71, 72, 74, 75]
# 0.9431842631605194
# 90 0.5896457596001232 0.8954345621714725
# [88, 89, 91, 92]
# 0.9718817628143099
# 121 0.8985724721838343 0.9658175243621256
# [119, 120, 122, 123]
# 0.9826287874066983
# 215 0.8199441624365482 0.9627604060913706
# [213, 214, 216, 217]
# 0.9984644670050762
# 6 0.11642385786802033 0.2539583756345178
# [4, 5, 7, 8]
# 0.28834200507614216
# 7 0.20814467005076145 0.329536421319797
# [5, 6, 8, 9]
# 0.35988435913705585
# 9 0.3946142131979696 0.4279834708121827
# [7, 8, 10, 11]
# 0.43632578521573606
# 10 0.4203071065989848 0.4728910453680203
# [8, 9, 11, 12]
# 0.4860370300602792
# 12 0.5427106598984771 0.5839221268242387
# [10, 11, 13, 14]
# 0.5942249935556789
# 13 0.621510152284264 0.6568089581019988
# [11, 12, 14, 15]
# 0.6656336595564325
# 17 0.6747208121827412 0.7754157360406092
# [15, 16, 18, 19]
# 0.8005894670050762
# 21 0.06327918781725889 0.5750223350253808
# [19, 20, 22, 23]
# 0.7029581218274112
# 22 0.5861649746192894 0.6920180203045685
# [20, 21, 23, 24]
# 0.7184812817258883
# 23 0.6144340101522843 0.7079401649746193
# [21, 22, 24, 25]
# 0.7313167036802031
# 27 0.7256192893401016 0.7767314720812182
# [25, 26, 28, 29]
# 0.7895095177664975
# 33 0.3474340101522843 0.7235289340101524
# [31, 32, 34, 35]
# 0.8175526649746194
# 34 0.7462385786802032 0.8169836294416244
# [32, 33, 35, 36]
# 0.8346698921319797
# 70 0.826964467005076 0.9412756345177666
# [68, 69, 71, 72]
# 0.9698534263959391
# 98 0.9070203045685279 0.973146192893401
# [96, 97, 99, 100]
# 0.9896776649746193
# 6 0.11198187676689837 0.24975564926286933
# [4, 5, 7, 8]
# 0.28419909238686203
# 7 0.208245603990555 0.3242036820479548
# [5, 6, 8, 9]
# 0.3531932015623047
# 9 0.3796845655198926 0.42530148396383705
# [7, 8, 10, 11]
# 0.43670571357482324
# 10 0.41606091134472295 0.4754432348435106
# [8, 9, 11, 12]
# 0.4902888157182075
# 12 0.5468808079057418 0.5821390633485615
# [10, 11, 13, 14]
# 0.5909536272092665
# 17 0.6516575142840908 0.7526816750024707
# [15, 16, 18, 19]
# 0.7779377151820657
# 21 0.06160369025945929 0.5694742721341701
# [19, 20, 22, 23]
# 0.6964419176028479
# 22 0.5906630234704466 0.6839574419083301
# [20, 21, 23, 24]
# 0.7072810465178009
# 23 0.5955736677827598 0.6889835489087326
# [21, 22, 24, 25]
# 0.7123360191902258
# 27 0.7122720627223472 0.76937178724272
# [25, 26, 28, 29]
# 0.7836467183728133
# 33 0.34065481136283793 0.7126433444888896
# [31, 32, 34, 35]
# 0.8056404777704025
# 34 0.7560719102922325 0.8060210454205281
# [32, 33, 35, 36]
# 0.8185083292026021
# 70 0.8041433776220985 0.9363556675221124
# [68, 69, 71, 72]
# 0.969408739997116
# 98 0.9042546076410327 0.9744664540004475
# [96, 97, 99, 100]
# 0.9920194155903013
# 11 0.6101576685905457 0.8517125248908997
# [9, 10, 12, 13]
# 0.9121012389659882
# 32 0.7729523181915283 0.9259485960006714
# [30, 31, 33, 34]
# 0.9641976654529572
# 15 0.6170799732208252 0.8633454203605652
# [13, 14, 16, 17]
# 0.9249117821455002
# 16 0.8728848695755005 0.9227164953947067
# [14, 15, 17, 18]
# 0.9351744018495083
# 153 0.7026678919792175 0.9362420201301574
# [151, 152, 154, 155]
# 0.9946355521678925
# 33 0.9059500098228455 0.9680292844772339
# [31, 32, 34, 35]
# 0.983549103140831
# 59 0.9232981204986572 0.9786185145378112
# [57, 58, 60, 61]
# 0.9924486130475998
# 3 0.08292917166866746 0.1097719087635054
# [1, 2, 4, 5]
# 0.1164825930372149
# 11 0.04441776710684274 0.37359903961584634
# [9, 10, 12, 13]
# 0.4558943577430973
# 12 0.3372869147659064 0.45729651860744297
# [10, 11, 13, 14]
# 0.4872989195678271
# 14 0.4883553421368547 0.5260024009603842
# [12, 13, 15, 16]
# 0.5354141656662665
# 15 0.48331332533013205 0.5676830732292918
# [13, 14, 16, 17]
# 0.5887755102040817
# 16 0.502280912364946 0.5673877551020408
# [14, 15, 17, 18]
# 0.5836644657863146
# 18 0.5618247298919568 0.597952581032413
# [16, 17, 19, 20]
# 0.606984543817527
# 19 0.4915246098439376 0.6273560924369748
# [17, 18, 20, 21]
# 0.661313963085234
# 24 0.6534453781512605 0.7362400960384153
# [22, 23, 25, 26]
# 0.756938775510204
# 32 0.2737094837935174 0.6499399759903961
# [30, 31, 33, 34]
# 0.7439975990396158
# 43 0.7890996398559423 0.8510732292917167
# [41, 42, 44, 45]
# 0.8665666266506602
# 52 0.7801200480192076 0.8714333733493398
# [50, 51, 53, 54]
# 0.8942617046818727
# 66 0.874093637454982 0.9353661464585834
# [64, 65, 67, 68]
# 0.9506842737094838
# 3 0.01800720288115246 0.08075870348139255
# [1, 2, 4, 5]
# 0.09644657863145259
# 4 0.12897959183673469 0.15794957983193278
# [2, 3, 5, 6]
# 0.1651920768307323
# 6 0.30756302521008405 0.3549111644657863
# [4, 5, 7, 8]
# 0.3667481992797119
# 10 0.40960384153661467 0.5774213685474189
# [8, 9, 11, 12]
# 0.61937575030012
# 12 0.4993517406962785 0.6453637454981992
# [10, 11, 13, 14]
# 0.6818667466986794
# 15 0.13123649459783915 0.5179735894357742
# [13, 14, 16, 17]
# 0.6146578631452582
# 16 0.4611284513805522 0.612765906362545
# [14, 15, 17, 18]
# 0.6506752701080432
# 20 0.4824969987995198 0.589983193277311
# [18, 19, 21, 22]
# 0.6168547418967587
# 22 0.4270828331332533 0.6155390156062425
# [20, 21, 23, 24]
# 0.6626530612244899
# 24 0.5967346938775511 0.6816590636254503
# [22, 23, 25, 26]
# 0.702890156062425
# 25 0.6391356542617047 0.7352863145258104
# [23, 24, 26, 27]
# 0.7593239795918367
# 26 0.7321008403361344 0.7812687575030013
# [24, 25, 27, 28]
# 0.7935607367947178
# 29 0.6813925570228091 0.7462857142857142
# [27, 28, 30, 31]
# 0.7625090036014406
# 30 0.6750060024009604 0.7590228091236495
# [28, 29, 31, 32]
# 0.7800270108043217
# 31 0.6630012004801921 0.777952581032413
# [29, 30, 32, 33]
# 0.8066904261704683
# 35 0.7766626650660264 0.8329123649459784
# [33, 34, 36, 37]
# 0.8469747899159663
# 36 0.755390156062425 0.835565426170468
# [34, 35, 37, 38]
# 0.8556092436974789
# 39 0.6064345738295318 0.8055990396158463
# [37, 38, 40, 41]
# 0.855390156062425
# 42 0.59015606242497 0.813358943577431
# [40, 41, 43, 44]
# 0.8691596638655462
# 50 0.8335654261704681 0.9030780312124851
# [48, 49, 51, 52]
# 0.9204561824729891
# 55 0.7670588235294118 0.879654261704682
# [53, 54, 56, 57]
# 0.9078031212484994
# 153 0.16163265306122448 0.8039759903961585
# [151, 152, 154, 155]
# 0.9645618247298919
# 6 0.38376950780312125 0.4355534213685474
# [4, 5, 7, 8]
# 0.448499399759904
# 8 0.41555822328931574 0.5503865546218488
# [6, 7, 9, 10]
# 0.5840936374549821
# 9 0.5900600240096039 0.6366458583433374
# [7, 8, 10, 11]
# 0.6482923169267707
# 13 0.6134453781512605 0.6792989195678272
# [11, 12, 14, 15]
# 0.6957623049219688
# 15 0.6704441776710685 0.7221344537815126
# [13, 14, 16, 17]
# 0.7350570228091237
# 25 0.7360384153661464 0.821608643457383
# [23, 24, 26, 27]
# 0.8430012004801921
# 29 0.803313325330132 0.8535318127250899
# [27, 28, 30, 31]
# 0.8660864345738295
# 33 0.5709003601440577 0.8181032412965186
# [31, 32, 34, 35]
# 0.8799039615846338
# 43 0.8626170468187275 0.9135270108043217
# [41, 42, 44, 45]
# 0.9262545018007202
# 56 0.8064825930372149 0.9193085234093636
# [54, 55, 57, 58]
# 0.9475150060024009
# 3 0.007683073229291717 0.1353469387755102
# [1, 2, 4, 5]
# 0.16726290516206482
# 6 0.40259303721488593 0.43836734693877555
# [4, 5, 7, 8]
# 0.4473109243697479
# 9 0.5221608643457383 0.5578775510204081
# [7, 8, 10, 11]
# 0.5668067226890756
# 11 0.442641056422569 0.52846818727491
# [9, 10, 12, 13]
# 0.5499249699879952
# 12 0.2957983193277311 0.5957953181272508
# [10, 11, 13, 14]
# 0.6707945678271309
# 15 0.6164705882352941 0.7170900360144057
# [13, 14, 16, 17]
# 0.7422448979591837
# 16 0.6754381752701081 0.7619711884753901
# [14, 15, 17, 18]
# 0.7836044417767107
# 18 0.74031212484994 0.7863967587034815
# [16, 17, 19, 20]
# 0.7979179171668668
# 21 0.7030492196878751 0.7424633853541416
# [19, 20, 22, 23]
# 0.7523169267707083
# 23 0.6320288115246099 0.7051620648259304
# [21, 22, 24, 25]
# 0.7234453781512605
# 24 0.5710444177671068 0.739234093637455
# [22, 23, 25, 26]
# 0.7812815126050421
# 25 0.745546218487395 0.796311524609844
# [23, 24, 26, 27]
# 0.8090028511404562
# 31 0.7675390156062425 0.8442448979591838
# [29, 30, 32, 33]
# 0.863421368547419
# 34 0.7983673469387755 0.8704057623049218
# [32, 33, 35, 36]
# 0.8884153661464586
# 38 0.7138055222088836 0.8016614645858343
# [36, 37, 39, 40]
# 0.8236254501800722
# 39 0.7424249699879952 0.8083361344537817
# [37, 38, 40, 41]
# 0.8248139255702281
# 53 0.8640576230492197 0.9195486194477791
# [51, 52, 54, 55]
# 0.9334213685474189
# 59 0.2823529411764706 0.8122256902761105
# [57, 58, 60, 61]
# 0.9446938775510204
# 13 0.6584078073501587 0.8686042070388794
# [11, 12, 14, 15]
# 0.9211533069610596
# 25 0.665319561958313 0.905120849609375
# [23, 24, 26, 27]
# 0.9650711715221405
# 13 0.26043689250946045 0.7333520531654358
# [11, 12, 14, 15]
# 0.8515808433294296
# 14 0.7864115834236145 0.8523603647947311
# [12, 13, 15, 16]
# 0.8688475601375103
# 31 0.42090076208114624 0.846636700630188
# [29, 30, 32, 33]
# 0.9530706852674484
# 9 0.6451753377914429 0.8213040709495545
# [7, 8, 10, 11]
# 0.8653362542390823
# 27 0.8487894535064697 0.9434612035751343
# [25, 26, 28, 29]
# 0.9671291410923004
# 73 0.8220494985580444 0.9590877056121826
# [71, 72, 74, 75]
# 0.9933472573757172
# 90 0.9193653464317322 0.9808425545692444
# [88, 89, 91, 92]
# 0.9962118566036224
# 21 0.5950217247009277 0.8633380055427551
# [19, 20, 22, 23]
# 0.930417075753212
# 33 0.7730585932731628 0.9228867769241333
# [31, 32, 34, 35]
# 0.9603438228368759
# 3 0.13642256902761105 0.1638799519807923
# [1, 2, 4, 5]
# 0.17074429771908764
# 6 0.10847539015606243 0.23199999999999998
# [4, 5, 7, 8]
# 0.26288115246098437
# 7 0.11918367346938775 0.27272509003601436
# [5, 6, 8, 9]
# 0.3111104441776711
# 9 0.27735894357743096 0.3623805522208884
# [7, 8, 10, 11]
# 0.3836359543817527
# 10 0.3305642256902761 0.4103934573829532
# [8, 9, 11, 12]
# 0.4303507653061225
# 13 0.08835534213685474 0.43243217286914765
# [11, 12, 14, 15]
# 0.5184513805522208
# 16 0.44484993997599037 0.5044321728691477
# [14, 15, 17, 18]
# 0.519327731092437
# 18 0.4745738295318127 0.6124657863145259
# [16, 17, 19, 20]
# 0.6469387755102041
# 25 0.08163265306122448 0.615577430972389
# [23, 24, 26, 27]
# 0.7490636254501801
# 26 0.7090996398559424 0.7479975990396157
# [24, 25, 27, 28]
# 0.7577220888355343
# 28 0.7133733493397358 0.7752466986794718
# [26, 27, 29, 30]
# 0.7907150360144057
# 29 0.7610564225690276 0.8086111944777912
# [27, 28, 30, 31]
# 0.8204998874549819
# 33 0.7954381752701081 0.8549243697478991
# [31, 32, 34, 35]
# 0.8697959183673469
# 37 0.80984393757503 0.861358943577431
# [35, 36, 38, 39]
# 0.8742376950780312
# 38 0.792797118847539 0.8788379351740696
# [36, 37, 39, 40]
# 0.9003481392557022
# 42 0.7907803121248499 0.8866842737094837
# [40, 41, 43, 44]
# 0.9106602641056423
# 69 0.843937575030012 0.9354141656662665
# [67, 68, 70, 71]
# 0.9582833133253301
# 80 0.8160384153661464 0.9379399759903961
# [78, 79, 81, 82]
# 0.9684153661464585
# 154 0.8070588235294117 0.9527298919567828
# [152, 153, 155, 156]
# 0.9891476590636255
# 3 0.041392557022809126 0.07104921968787516
# [1, 2, 4, 5]
# 0.07846338535414166
# 4 0.08725090036014406 0.0963361344537815
# [2, 3, 5, 6]
# 0.09860744297719087
# 6 0.08936374549819928 0.13864585834333734
# [4, 5, 7, 8]
# 0.15096638655462186
# 8 0.08480192076830732 0.2195906362545018
# [6, 7, 9, 10]
# 0.2532878151260504
# 11 0.10506602641056423 0.22131092436974792
# [9, 10, 12, 13]
# 0.25037214885954384
# 13 0.0 0.26994477791116445
# [11, 12, 14, 15]
# 0.3374309723889556
# 14 0.2443217286914766 0.32294837935174064
# [12, 13, 15, 16]
# 0.3426050420168067
# 16 0.17795918367346938 0.3839783913565426
# [14, 15, 17, 18]
# 0.43548319327731094
# 17 0.31092436974789917 0.5004267707082833
# [15, 16, 18, 19]
# 0.5478023709483794
# 21 0.36595438175270106 0.5613925570228091
# [19, 20, 22, 23]
# 0.6102521008403361
# 23 0.5435294117647059 0.6042785114045619
# [21, 22, 24, 25]
# 0.6194657863145259
# 25 0.6237214885954382 0.6675186074429773
# [23, 24, 26, 27]
# 0.678467887154862
# 31 0.004897959183673469 0.5909723889555822
# [29, 30, 32, 33]
# 0.7374909963985594
# 32 0.6618007202881152 0.7384129651860745
# [30, 31, 33, 34]
# 0.7575660264105643
# 35 0.7296998799519808 0.7701800720288116
# [33, 34, 36, 37]
# 0.7803001200480193
# 37 0.7525090036014406 0.8033013205282113
# [35, 36, 38, 39]
# 0.815999399759904
# 42 0.7686914765906363 0.8520144057623049
# [40, 41, 43, 44]
# 0.872845138055222
# 46 0.8045138055222089 0.859438175270108
# [44, 45, 47, 48]
# 0.8731692677070828
# 49 0.7524609843937575 0.8384345738295318
# [47, 48, 50, 51]
# 0.8599279711884753
# 70 0.7282112845138056 0.8676206482593036
# [68, 69, 71, 72]
# 0.9024729891956782
# 99 0.9001680672268908 0.9517887154861946
# [97, 98, 100, 101]
# 0.9646938775510204
# 114 0.8451380552220888 0.9376902761104443
# [112, 113, 115, 116]
# 0.960828331332533
# 132 0.9006002400960385 0.9614213685474191
# [130, 131, 133, 134]
# 0.9766266506602641
# 207 0.8155582232893157 0.9549387755102041
# [205, 206, 208, 209]
# 0.989783913565426
# 9 0.09378151260504201 0.23770468187274912
# [7, 8, 10, 11]
# 0.27368547418967587
# 10 0.2186794717887155 0.3222521008403361
# [8, 9, 11, 12]
# 0.34814525810324126
# 14 0.36417767106842736 0.550060024009604
# [12, 13, 15, 16]
# 0.5965306122448979
# 18 0.44941176470588234 0.6305114045618246
# [16, 17, 19, 20]
# 0.6757863145258103
# 20 0.4801920768307323 0.6401464585834333
# [18, 19, 21, 22]
# 0.6801350540216087
# 21 0.5268667466986795 0.6858661464585835
# [19, 20, 22, 23]
# 0.7256159963985594
# 24 0.7024249699879952 0.7429339735894358
# [22, 23, 25, 26]
# 0.7530612244897961
# 27 0.4097959183673469 0.715937575030012
# [25, 26, 28, 29]
# 0.7924729891956783
# 38 0.6162785114045618 0.7971476590636255
# [36, 37, 39, 40]
# 0.8423649459783914
# 53 0.862953181272509 0.9251764705882353
# [51, 52, 54, 55]
# 0.9407322929171669
# 73 0.34847539015606244 0.8371380552220888
# [71, 72, 74, 75]
# 0.9593037214885956
# 90 0.49373349339735895 0.8813445378151259
# [88, 89, 91, 92]
# 0.9782472989195679
# 121 0.876110444177671 0.9645042016806723
# [119, 120, 122, 123]
# 0.9866026410564226
# 215 0.8121008403361345 0.9573109243697479
# [213, 214, 216, 217]
# 0.9936134453781513
# 6 0.1033373349339736 0.22908043217286914
# [4, 5, 7, 8]
# 0.26051620648259305
# 7 0.18338535414165666 0.29669387755102045
# [5, 6, 8, 9]
# 0.32502100840336134
# 9 0.35591836734693877 0.3959717887154862
# [7, 8, 10, 11]
# 0.40598514405762304
# 10 0.38213685474189674 0.4427624549819928
# [8, 9, 11, 12]
# 0.4579188550420168
# 12 0.5089075630252101 0.5508874924969989
# [10, 11, 13, 14]
# 0.561382474864946
# 13 0.5666746698679472 0.6174577674819928
# [11, 12, 14, 15]
# 0.6301535418855042
# 17 0.6343817527010804 0.7204129651860744
# [15, 16, 18, 19]
# 0.741920768307323
# 21 0.06444177671068427 0.5413493397358943
# [19, 20, 22, 23]
# 0.6605762304921969
# 22 0.562593037214886 0.6507899159663866
# [20, 21, 23, 24]
# 0.6728391356542618
# 23 0.5755102040816327 0.6650792316926771
# [21, 22, 24, 25]
# 0.6874714885954382
# 27 0.7021368547418968 0.7445858343337335
# [25, 26, 28, 29]
# 0.7551980792316926
# 33 0.3381512605042017 0.7057767106842736
# [31, 32, 34, 35]
# 0.7976830732292918
# 34 0.7199039615846339 0.7947539015606243
# [32, 33, 35, 36]
# 0.8134663865546219
# 70 0.8102280912364946 0.9242160864345739
# [68, 69, 71, 72]
# 0.9527130852340937
# 98 0.8957983193277311 0.9607683073229293
# [96, 97, 99, 100]
# 0.9770108043217287

# %%
# Celex ALL - Training - WRITING - WORD accuracy plot 
smooth = True
fs=7
ind =1

if smooth:
    plt.plot(perf_250,savgol_filter(np.squeeze(normal_cel['trainPerf'][:-1,ind]),fs,1),color='forestgreen',linewidth=4,label='Regular')
    plt.plot(perf_250,savgol_filter(np.squeeze(lds_cel['trainPerf'][:-1,ind]),fs,1),color='firebrick',linewidth=4,label='LdS')
    plt.plot(perf_250,savgol_filter(np.squeeze(leave_cel['trainPerf'][:-1,ind]),fs,1),color='tomato',linewidth=4,label='Replay')
    plt.plot(perf_250,savgol_filter(np.squeeze(vene_cel['trainPerf'][:-1,ind]),fs,1),color='springgreen',linewidth=4,label="Intervene")
    plt.plot(perf_250,savgol_filter(np.squeeze(vl_cel['trainPerf'][:-1,ind]),fs,1),color='dodgerblue',linewidth=4,label="I+R")
else:
    k=42
plt.title("Celex dataset - WRITING - word accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_250,xticklabels)
plt.legend(loc=4)
plt.ylim([0.65, 1.02])
plt.axvline(125,color='k')
plt.show()

# %%
# Celex ALL - Training - READING - WORD accuracy plot 
smooth = True
fs=7
ind =4
if smooth:
    plt.plot(perf_250,savgol_filter(np.squeeze(normal_cel['trainPerf'][:-1,ind]),fs,1),color='forestgreen',linewidth=4,label='Regular')
    plt.plot(perf_250,savgol_filter(np.squeeze(lds_cel['trainPerf'][:-1,ind]),fs,1),color='firebrick',linewidth=4,label='LdS')
    plt.plot(perf_250,savgol_filter(np.squeeze(leave_cel['trainPerf'][:-1,ind]),fs,1),color='tomato',linewidth=4,label='Replay')
    plt.plot(perf_250,savgol_filter(np.squeeze(vene_cel['trainPerf'][:-1,ind]),fs,1),color='springgreen',linewidth=4,label="Intervene")
    plt.plot(perf_250,savgol_filter(np.squeeze(vl_cel['trainPerf'][:-1,ind]),fs,1),color='dodgerblue',linewidth=4,label="I+R")
else:
    k=42
plt.title("Celex dataset - READING - word accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_250,xticklabels)
plt.legend(loc=4)
plt.ylim([0.65, 1.02])
plt.axvline(125,color='k')
plt.show()

# %%
# Make Figure with 4 subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
#fig.tight_layout()
#fig.set_figheight(5)
#fig.set_figwidth(5)
fig.suptitle("CELEX corpus", fontsize=15, weight='bold' )


# cellex - Training - Word accuracy plot - all regimes - Writing
fs = 9
ind =1
ax1.plot(perf,savgol_filter(np.squeeze(normal_cel['trainPerf'][:-1,ind]),fs,1),color='forestgreen',linewidth=4,label='Regular')
ax1.plot(perf,savgol_filter(np.squeeze(lds_cel['trainPerf'][:-1,ind]),fs,1),color='firebrick',linewidth=4,label='LdS')
ax1.plot(perf,savgol_filter(np.squeeze(leave_cel['trainPerf'][:-1,ind]),fs,1),color='tomato',linewidth=4,label='Replay')
ax1.plot(perf, savgol_filter(np.squeeze(vene_cel['trainPerf'][:-1,ind]),fs,1),color='springgreen',linewidth=4,label='Intervene')
ax1.plot(perf, savgol_filter(np.squeeze(vl_cel['trainPerf'][:-1,ind]),fs,1),color='dodgerblue',linewidth=4,label='I + R')

ax1.set_title("Training - Writing module",{'fontsize':12})
ax1.set_ylabel("Word accuracy")
ax1.set_xticks(xticks)
ax1.legend(loc=4, prop={'size': 8})
ax1.set_ylim([0.75, 1.0])
ax1.set_xlim([0, 250])
ax1.axvline(125,color='k')


# cellex - Training - Word accuracy plot - all regimes - Reading
ind =4
ax2.plot(perf,savgol_filter(np.squeeze(normal_cel['trainPerf'][:-1,ind]),fs,1),color='forestgreen',linewidth=4,label='Regular')
ax2.plot(perf,savgol_filter(np.squeeze(lds_cel['trainPerf'][:-1,ind]),fs,1),color='firebrick',linewidth=4,label='LdS')
ax2.plot(perf,savgol_filter(np.squeeze(leave_cel['trainPerf'][:-1,ind]),fs,1),color='tomato',linewidth=4,label='Replay')
ax2.plot(perf, savgol_filter(np.squeeze(vene_cel['trainPerf'][:-1,ind]),fs,1),color='springgreen',linewidth=4,label='Intervene')
ax2.plot(perf, savgol_filter(np.squeeze(vl_cel['trainPerf'][:-1,ind]),fs,1),color='dodgerblue',linewidth=4,label='I + R')

ax2.set_title("Training - Reading module",{'fontsize':12})
ax2.set_ylabel("Word accuracy")
ax2.set_xticks(xticks)
ax2.legend(loc=4, prop={'size': 8})
ax2.set_xlim([0, 250])
ax2.set_ylim([0.75, 1.0])
ax2.axvline(125,color='k')

# cellex - Training - Word ratio accuracy plots
ax3.plot(perf,savgol_filter(np.squeeze(normal_cel['trainPerf'][:-1,1]),fs,1),color='forestgreen',linewidth=4,label='Regular - true spelling')
ax3.plot(perf,savgol_filter(np.squeeze(lds_cel['trainPerf'][:-1,1]),fs,1),color='firebrick',linewidth=4,label='LdS - true spelling')
ax3.plot(perf,savgol_filter(np.squeeze(lds_cel['lds_ratios']),fs,1),color='tomato',linewidth=4,label='LdS - alt. spellings')
ax3.plot(perf,savgol_filter(np.squeeze(normal_cel['lds_ratios']),fs,1),color='springgreen',linewidth=4,label='Regular - alt. spellings')

ax3.set_title("Training - Writing - Word correctnesses")
ax3.set_ylabel("Ratio")
ax3.set_xlabel("Epochs")
ax3.set_xticks(xticks)
ax3.legend(loc=5, prop={'size': 8})
ax3.set_xlim([0, 250])
ax3.set_ylim([0, 1])
ax3.axvline(125,color='k')


# cellex - Testing - Word ratio accuracy plots
ax4.plot(perf,savgol_filter(np.squeeze(normal_cel['testPerf'][:-1,1]),fs,1),color='forestgreen',linewidth=4,label='Regular - true spelling')
ax4.plot(perf,savgol_filter(np.squeeze(lds_cel['testPerf'][:-1,1]),fs,1),color='firebrick',linewidth=4,label='LdS - true spelling')
ax4.plot(perf,savgol_filter(np.squeeze(lds_cel['lds_ratios_test'][:-1]),fs,1),color='tomato',linewidth=4,label='LdS - alt. spellings')
ax4.plot(perf,savgol_filter(np.squeeze(normal_cel['lds_ratios_test'][:-1]),fs,1),color='springgreen',linewidth=4,label='Regular - alt. spellings')

ax4.set_title("Testing - Writing - Word correctnesses")
ax4.set_ylabel("Ratio")
ax4.set_xlabel("Epochs")
ax4.set_xticks(xticks)
ax4.legend(loc=5, prop={'size': 8})
ax4.set_xlim([0, 250])
ax4.set_ylim([0, 1])
ax4.axvline(125,color='k')

# %%
plt.close('close all')

# %% [markdown]
# ## Investigate writing module in more detail

# %%
# Fibel - Training - Word ratio accuracy plots
plt.plot(epochs,savgol_filter(np.squeeze(lds_fibel['lds_ratio']),5,1),color='firebrick',linewidth=4,label='LdS model - alt. spellings')
plt.plot(epochs,savgol_filter(np.squeeze(lds_fibel['corr_ratio']),5,1),color='tomato',linewidth=4,label='LdS model - single spelling')
plt.plot(epochs,savgol_filter(np.squeeze(normal_fibel['lds_ratio']),5,1),color='forestgreen',linewidth=4,label='Reg. model - alt. spellings')
plt.plot(epochs,savgol_filter(np.squeeze(normal_fibel['corr_ratio']),5,1),color='springgreen',linewidth=4,label='Reg. model - single spellings')

plt.title("Fibel dataset - Ratio of correct words")
plt.ylabel("Ratio")
plt.xlabel("Epochs")
#plt.xticks(xticks_p,xticklabels)
plt.legend(loc=4)
#plt.ylim([0, 0.6])
plt.axvline(250,color='k')
plt.show()

# %%
# CELEX - Training - Word ratio accuracy plots

smooth = True

if smooth:
    plt.plot(epochs,savgol_filter(np.squeeze(lds_cel['lds_ratio']),15,1),color='firebrick',linewidth=4,label='LdS model - all spellings')
    plt.plot(epochs,savgol_filter(np.squeeze(lds_cel['corr_ratio']),15,1),color='tomato',linewidth=4,label='LdS model - 1 spelling')
    plt.plot(epochs,savgol_filter(np.squeeze(normal_cel['lds_ratio']),15,1),color='forestgreen',linewidth=4,label='Reg. model - all spellings')
    plt.plot(epochs,savgol_filter(np.squeeze(normal_cel['corr_ratio']),15,1),color='springgreen',linewidth=4,label='Reg. model - 1 spelling')
else:
    plt.plot(epochs,lds_cel['lds_ratio'],color='firebrick',linewidth=4,label='LdS model - all spellings')
    plt.plot(epochs,lds_cel['corr_ratio'],color='tomato',linewidth=4,label='LdS model - 1 spelling')
    plt.plot(epochs,normal_cel['lds_ratio'],color='forestgreen',linewidth=4,label='Reg. model - all spellings')
    plt.plot(epochs,normal_cel['corr_ratio'],color='springgreen',linewidth=4,label='Reg. model - 1 spelling')
    
plt.title("Celex dataset - Ratio of correct words")
plt.ylabel("Ratio")
plt.xlabel("Epochs")
plt.xticks(xticks_500,xticklabels)
plt.legend(loc=5)
#plt.ylim([0, 0.6])
plt.axvline(250,color='k')
plt.show()

# %%
# Fibel - Training - Loss
plt.plot(epochs,savgol_filter(np.squeeze(lds_fibel['lds_loss']),3,1),color='firebrick',linewidth=4,label='LdS model - lds loss')
plt.plot(epochs,savgol_filter(np.squeeze(lds_fibel['reg_loss']),3,1),color='tomato',linewidth=4,label='LdS model - regular loss')
plt.plot(epochs,savgol_filter(np.squeeze(normal_fibel['lds_loss']),5,1),color='forestgreen',linewidth=4,label='Reg. model - lds loss')
plt.plot(epochs,savgol_filter(np.squeeze(normal_fibel['reg_loss']),5,1),color='springgreen',linewidth=4,label='Reg. model - regular loss')

plt.title("Fibel dataset - Loss development")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.xticks(xticks_p,xticklabels)
plt.legend(loc='best')
plt.ylim([0, 0.5])
plt.axvline(250,color='k')
plt.show()

# %%
# CELEX - Training - Loss
plt.plot(epochs,savgol_filter(np.squeeze(lds_cel['lds_loss']),3,1),color='firebrick',linewidth=4,label='LdS model - lds loss')
plt.plot(epochs,savgol_filter(np.squeeze(lds_cel['reg_loss']),3,1),color='tomato',linewidth=4,label='LdS model - regular loss')
plt.plot(epochs,savgol_filter(np.squeeze(normal_cel['lds_loss']),5,1),color='forestgreen',linewidth=4,label='Reg. model - lds loss')
plt.plot(epochs,savgol_filter(np.squeeze(normal_cel['reg_loss']),5,1),color='springgreen',linewidth=4,label='Reg. model - regular loss')

plt.title("Celex dataset - Loss development")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.xticks(xticks_p,xticklabels)
plt.legend(loc='best')
plt.ylim([0, 0.5])
plt.axvline(250,color='k')
plt.show()

# %% [markdown]
# ## Investigate READING

# %%
# CELEX - Training - Loss
plt.plot(epochs,savgol_filter(np.squeeze(lds_cel['read_losses']),3,1),color='firebrick',linewidth=4,label='LdS model - lds loss')
#plt.plot(epochs,savgol_filter(np.squeeze(lds_fibel['reg_loss']),3,1),color='tomato',linewidth=4,label='LdS model - regular loss')
plt.plot(epochs,savgol_filter(np.squeeze(normal_cel['read_losses']),5,1),color='forestgreen',linewidth=4,label='Reg. model - lds loss')
#plt.plot(epochs,savgol_filter(np.squeeze(normal_fibel['reg_loss']),5,1),color='springgreen',linewidth=4,label='Reg. model - regular loss')

plt.title("Celex dataset - Loss development")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.xticks(xticks_p,xticklabels)
plt.legend(loc='best')
plt.ylim([0, 0.5])
plt.axvline(250,color='k')
plt.show()

# %%
int(np.random.uniform(0,9))

# %%
path = '/Users/jannisborn/Desktop/LDS_Data/data/childlex_alt_targets.npy'

alt_targs_raw = np.load(path)
alt_targs = np.array([np.array(d,dtype=np.int8) for d in alt_targs_raw])

# %%
path2 = '/Users/jannisborn/Desktop/LDS_Data/data/childlex_old.npz'
d = np.load(path2)

# %%
print(d['words'].shape)

# %%
path2 = '/Users/jannisborn/Desktop/LDS_Data/data/childlex_alt_targets_big(not used).npy'
d = np.load(path2)""

# %%
import io 
pathreg = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/normal_run_0/evaluation/'
pathlds = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/lds_run_0/evaluation/'
path = '/Users/jannisborn/Desktop/LDS_Data/TrainedModels/childlex/'
epoch = 125
task = 'writing'
data = 'train'
mode = 'lds' # If lds, then it means errors that LdS model made but regular not

def error_diff(pathreg,pathlds,path,epoch,task,data,mode):
    epoch_lds = 120
    regfile = pathreg+task.upper()+'mistakes_'+data+'_data_epoch'+str(epoch)+'.txt'
    ldsfile = pathlds+task.upper()+'mistakes_'+data+'_data_epoch'+str(epoch_lds)+'.txt'
    
    newfile = io.open(path+'error_diff_'+task+'_'+mode.upper()+'_'+data+'_e'+str(epoch)+'.txt','a',encoding='utf8')
    
    with io.open(regfile, mode="r", encoding="utf-8") as rf:
        cont_reg = rf.readlines()
        cont_reg = [x.strip() for x in cont_reg] 

        with io.open(ldsfile, mode="r", encoding="utf-8") as lf:
            cont_lds = lf.readlines()
            cont_lds = [x.strip() for x in cont_lds]    
            
            
            if mode == 'reg':
                counter = 0
                print(len(cont_reg), " mistakes")
                for k in range(len(cont_reg)):
                    ps_reg = cont_reg[k].split()[3]
                    
                    if not any(ps_reg in clds.split()[3] for clds in cont_lds):
                        print(cont_reg[k],file=newfile)
                        counter += 1
                print("Mistakes only the ", mode," model made ", counter)
                        
                        
            elif mode == 'lds':
                counter = 0
                print(len(cont_lds), " mistakes")
                for k in range(len(cont_lds)):
                    
                    ps_lds = cont_lds[k].split()[3]
                    
                    if not any(ps_lds in creg.split()[3] for creg in cont_reg):
                        print(cont_lds[k],file=newfile)
                        counter += 1
                print("Mistakes only the ", mode," model made ", counter)


                
error_diff(pathreg,pathlds,path,epoch,task,data,mode)
mode = 'reg'
print("NOW REG MODE")
error_diff(pathreg,pathlds,path,epoch,task,data,mode)

# %%
lt = []
epochs = 250
learn_type = 'intervened + interleaved'
regime = 'lds'

for epoch in range(epochs):
    
    lt.append(regime)
    
    if learn_type == 'lds' or learn_type == 'intervened':

        if epochs // 2 == epoch and regime == 'lds':
            regime = 'normal'

    # In interleaved regime, in regular training (2nd half), every 5th epoch is again LdS epoch
    if learn_type == 'interleaved':

        if epoch > epochs // 2 and epoch % 5 == 0:
            regime = 'lds'

        elif epoch > epochs // 2 and regime == 'lds':
            regime = 'normal'

    # In intervened regime, within LdS training (1st half), every 10th epoch is a regular epoch
    elif learn_type == 'intervened':

        if epoch < epochs // 2 and epoch % 10 == 0 and epoch > 0:
            regime = 'normal'

        elif epoch < epochs // 2 and regime == 'normal':
            regime = 'lds'

    # In intervened+interleaved regime, both other regimes are combined
    elif learn_type == 'intervened + interleaved':

        if epoch < epochs // 2 and epoch % 10 == 0 and epoch > 0:
            regime = 'normal'

        elif epoch < epochs // 2 and regime == 'normal':
            regime = 'lds'

        elif epoch > epochs // 2 and epoch % 5 == 0:
            regime = 'lds'

        elif epoch > epochs // 2 and regime == 'lds':
            regime = 'normal'
            
print(lt)
