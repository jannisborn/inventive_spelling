# %%
import sys,os
import numpy as np
#import matplotlib
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline
#%matplotlib notebook

# %%
normal_child = np.load('/Users/jannisborn/Dropbox/GitHub/LSTM/Models/childlex/normal_run_6/metrics.npz')
lds_child    = np.load('/Users/jannisborn/Dropbox/GitHub/LSTM/Models/childlex/lds_run_7/metrics.npz')
normal_fibel = np.load('/Users/jannisborn/Dropbox/GitHub/LSTM/Models/fibel/normal_run_1/metrics.npz')
lds_fibel    = np.load('/Users/jannisborn/Dropbox/GitHub/LSTM/Models/fibel/lds_run_2/metrics.npz')

epochs = np.arange(500)
perf_x = np.arange(50)
xticks_e = np.arange(50,501,50)
xticks_p = np.arange(5,51,5)
xticklabels = xticks_e
print(xticks_p)
print(xticklabels)
# Out:
# [ 5 10 15 20 25 30 35 40 45 50]
# [ 50 100 150 200 250 300 350 400 450 500]

# %%
normal_child_train = normal_data_f['trainPerf']
testPerf_n = normal_data_f['testPerf']
lds_ratio_n = normal_data_f['lds_ratio']
corr_ratio_n = normal_data_f['corr_ratio']
lds_loss_n = normal_data_f['lds_loss']
reg_loss_n = normal_data_f['reg_loss']


trainPerf_l = lds_data_f['trainPerf']
testPerf_l = lds_data_f['testPerf']
lds_ratio_l = lds_data_f['lds_ratio']
corr_ratio_l = lds_data_f['corr_ratio']
lds_loss_l = lds_data_f['lds_loss']
reg_loss_l = lds_data_f['reg_loss']

# %%
# Fibel - Training - Token accuracy plot 
plt.plot(perf_x,lds_fibel['trainPerf'][:-1,0],color='firebrick',linewidth=4,label='LdS writing module')
plt.plot(perf_x,lds_fibel['trainPerf'][:-1,3],color='tomato',linewidth=4,label='LdS reading module')
plt.plot(perf_x,normal_fibel['trainPerf'][:-1,0],color='forestgreen',linewidth=4,label='Regular writing module')
plt.plot(perf_x, normal_fibel['trainPerf'][:-1,3],color='springgreen',linewidth=4,label='Regular reading module')

plt.title("Fibel dataset - Token accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_p,xticklabels)
plt.legend(loc=4)
plt.ylim([0.5, 1.02])
plt.axvline(25,color='k')
plt.show()

# %%
# Fibel - Training - Word accuracy plot 
plt.plot(perf_x,lds_fibel['trainPerf'][:-1,1],color='firebrick',linewidth=4,label='LdS writing module')
plt.plot(perf_x,lds_fibel['trainPerf'][:-1,4],color='tomato',linewidth=4,label='LdS reading module')
plt.plot(perf_x,normal_fibel['trainPerf'][:-1,1],color='forestgreen',linewidth=4,label='Regular writing module')
plt.plot(perf_x, normal_fibel['trainPerf'][:-1,4],color='springgreen',linewidth=4,label='Regular reading module')
plt.title("Fibel dataset - Word accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_p,xticklabels)
plt.legend(loc=4)
#plt.ylim([0.5, 1.02])
plt.axvline(25,color='k')
plt.show()

# %%
# Childlex - Training - Token accuracy plot 
plt.plot(perf_x,lds_child['trainPerf'][:-1,0],color='firebrick',linewidth=4,label='LdS writing module')
plt.plot(perf_x,lds_child['trainPerf'][:-1,3],color='tomato',linewidth=4,label='LdS reading module')
plt.plot(perf_x,normal_child['trainPerf'][:-1,0],color='forestgreen',linewidth=4,label='Regular writing module')
plt.plot(perf_x, normal_child['trainPerf'][:-1,3],color='springgreen',linewidth=4,label='Regular reading module')

plt.title("Childlex dataset - Token accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_p,xticklabels)
plt.legend(loc=4)
plt.ylim([0.5, 1.02])
plt.axvline(25,color='k')
plt.show()

# %%
# Childlex - Training - Token accuracy plot 
plt.plot(perf_x,lds_child['trainPerf'][:-1,1],color='firebrick',linewidth=4,label='LdS writing module')
plt.plot(perf_x,lds_child['trainPerf'][:-1,4],color='tomato',linewidth=4,label='LdS reading module')
plt.plot(perf_x,normal_child['trainPerf'][:-1,1],color='forestgreen',linewidth=4,label='Regular writing module')
plt.plot(perf_x, normal_child['trainPerf'][:-1,4],color='springgreen',linewidth=4,label='Regular reading module')

plt.title("Childlex dataset - Token accuracy - Training data")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.xticks(xticks_p,xticklabels)
plt.legend(loc=4)
plt.ylim([0.5, 1.02])
plt.axvline(25,color='k')
plt.show()

# %%
plt.plot(epochs_n,lds_loss_l,'-b',label='lds_l')
plt.plot(epochs_n,lds_loss_n,'-c',label='lds_n')
plt.plot(epochs_n, reg_loss_l,'-r',label='reg_l')
plt.plot(epochs_n,reg_loss_n,'-m',label='reg_n')
plt.ylim([0, 0.35])

# for lds network the loss  
plt.legend(loc=4)
plt.show()

# %%
el = np.arange(101)
en = np.arange(51)

# Performance columns indices
# 0 - write_token_acc
# 1 - write_word_acc
# 2 - write_old_acc
# 3 - read_token_acc
# 4 - read_word_acc
# 5 - read_old_acc



plt.plot(el,testPerf_l[:,3],'--b',label='LdS - Training - Reading - Token')
plt.plot(en,testPerf_n[:,3],'--c',label='Regular - Training - Reading - Token')
#plt.ylim([0.2, 0.5])



# for lds network the loss  
plt.legend(loc=4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-d8ebf9e27f91> in <module>()
#      12
#      13
# ---> 14 plt.plot(el,testPerf_l[:,3],'--b',label='LdS - Training - Reading - Token')
#      15 plt.plot(en,testPerf_n[:,3],'--c',label='Regular - Training - Reading - Token')
#      16 #plt.ylim([0.2, 0.5])
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# ...

# %%
plot(np.arange(50),normal_fibel['trainPerf'][:-1,1])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-28efce09c0a4> in <module>()
#      15     x = np.dot(i, [1, 1.1, 1.2, 1.3])
#      16     y = x ** 2
# ---> 17     color = next(ax._get_lines.color_cycle)
#      18     plt.plot(x, y, linestyle='', markeredgecolor='none', marker=marker.next(), color=color, label = str(i))
#      19     plt.plot(x, y, linestyle='-', color = color)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'color_cycle'

# %%
foo(3)
# Out:
# 15
# 12
